# %%
import torch
from ultralytics import YOLO

# %%
model = YOLO("models/yolo26s-pose.pt")

# %%
results = model.train(
    project="orthognatic",
    name="ep300-imgsz640-defaug",
    data="./yolo_dataset/data.yaml", 
    epochs=300, 
    imgsz=640
    )
# Out:
# Ultralytics 8.4.115 🚀 Python-3.12.3 torch-2.13.0+cu130 CUDA:0 (NVIDIA GeForce RTX 3060 Laptop GPU, 5806MiB)
# ...
